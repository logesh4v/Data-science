# %% [markdown]
# # **plant dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
plant=pd.read_csv("/content/PlantGrowth.csv")

# %%
plant.head(5)
# Out:
#    observation  weight group
# 0            1    4.17  ctrl
# 1            2    5.58  ctrl
# 2            3    5.18  ctrl
# 3            4    6.11  ctrl
# 4            5    4.50  ctrl

# %%
data=plant.pivot(index="observation",columns="group",values="weight")
data
# Out:
# group        ctrl  trt1  trt2
# observation
# 1            4.17  4.81  6.31
# 2            5.58  4.17  5.12
# 3            5.18  4.41  5.54
# 4            6.11  3.59  5.50
# 5            4.50  5.87  5.37
# 6            4.61  3.83  5.29
# 7            5.17  6.03  4.92
# 8            4.53  4.89  6.15
# 9            5.33  4.32  5.80
# 10           5.14  4.69  5.26

# %%
data1=plant.pivot_table(index="group",values="weight")
data1
# Out:
#        weight
# group
# ctrl    5.032
# trt1    4.661
# trt2    5.526

# %% [markdown]
# ## **Match** **data**

# %%
match=pd.read_csv("/content/odi-batting.csv")
match.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-9bf2e71404c3> in <module>
# ----> 1 match=pd.read_csv("/content/odi-batting.csv")
#       2 match.head(10)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
x=match[match["Country"]=="India"]
y=x.groupby("Player")["Runs","ScoreRate"].mean()
y.sort_values(ascending=False,by="Runs").head(10)

# %%
x=match[(match['Country']=="India")&(match['Player']=="Sachin R Tendulkar")]
x
y=x.groupby('MatchDate')['Runs'].mean()
y
