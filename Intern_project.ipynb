# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ta=pd.read_csv("/content/BankChurners.csv")

# %%
ta.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
ta.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
ta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10127 entries, 768805383 to 714337233
# Data columns (total 22 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   Attrition_Flag                                                                                                                      10127 non-null  object
#  1   Customer_Age                                                                                                                        10127 non-null  int64
#  2   Gender                                                                                                                              10127 non-null  object
# ...

# %%
ta.max()
# Out:
# CLIENTNUM                                                                                                                                     828343083
# Attrition_Flag                                                                                                                        Existing Customer
# Customer_Age                                                                                                                                         73
# Gender                                                                                                                                                M
# Dependent_count                                                                                                                                       5
# Education_Level                                                                                                                                 Unknown
# ...

# %%
ta.min()
# Out:
# CLIENTNUM                                                                                                                                     708082083
# Attrition_Flag                                                                                                                        Attrited Customer
# Customer_Age                                                                                                                                         26
# Gender                                                                                                                                                F
# Dependent_count                                                                                                                                       0
# Education_Level                                                                                                                                 College
# ...

# %%
ta.mean()
# Out:
# <ipython-input-14-151cf3da0b8f>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ta.mean()
# CLIENTNUM                                                                                                                             7.391776e+08
# Customer_Age                                                                                                                          4.632596e+01
# Dependent_count                                                                                                                       2.346203e+00
# Months_on_book                                                                                                                        3.592841e+01
# ...

# %%
df=ta.iloc[:,5]
df
# Out:
# 0        High School
# 1           Graduate
# 2           Graduate
# 3        High School
# 4         Uneducated
#             ...
# 10122       Graduate
# 10123        Unknown
# 10124    High School
# 10125       Graduate
# 10126       Graduate
# Name: Education_Level, Length: 10127, dtype: object

# %%
ta.isnull()
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0          False           False         False   False            False
# 1          False           False         False   False            False
# 2          False           False         False   False            False
# 3          False           False         False   False            False
# 4          False           False         False   False            False
# ...          ...             ...           ...     ...              ...
# 10122      False           False         False   False            False
# 10123      False           False         False   False            False
# 10124      False           False         False   False            False
# 10125      False           False         False   False            False
# 10126      False           False         False   False            False
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# ...

# %%
ta.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
sns.heatmap(ta.isnull())

# %%
ta['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
ta.nunique()
# Out:
# CLIENTNUM                                                                                                                             10127
# Attrition_Flag                                                                                                                            2
# Customer_Age                                                                                                                             45
# Gender                                                                                                                                    2
# Dependent_count                                                                                                                           6
# Education_Level                                                                                                                           7
# Marital_Status                                                                                                                            4
# ...

# %%
ta.shape
# Out:
# (10127, 23)

# %%
ta["Card_Category"].unique
# Out:
# <bound method Series.unique of 0          Blue
# 1          Blue
# 2          Blue
# 3          Blue
# 4          Blue
#           ...
# 10122      Blue
# 10123      Blue
# 10124      Blue
# 10125      Blue
# 10126    Silver
# Name: Card_Category, Length: 10127, dtype: object>

# %%
ta[(ta["Card_Category"]=="Blue")&(ta["Gender"]=="M")&(ta['Credit_Limit']<2000)]
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 711314058  Existing Customer            49      M                2
# 719712633  Existing Customer            64      M                1
# 713572683  Existing Customer            44      M                3
# 709531908  Existing Customer            53      M                3
# 708868233  Attrited Customer            68      M                0
# ...                      ...           ...    ...              ...
# 712132383  Existing Customer            44      M                4
# 789613083  Existing Customer            47      M                3
# 711856683  Existing Customer            51      M                3
# 712788258  Existing Customer            48      M                3
# 711210633  Existing Customer            51      M                3
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# ...

# %%
b=ta.groupby("Card_Category").mean().sort_values(ascending="True",by="Credit_Limit")
b
# Out:
#                Customer_Age  Dependent_count  Months_on_book  \
# Card_Category
# Blue              46.372404         2.336477       35.960682
# Silver            45.679279         2.439640       35.452252
# Gold              45.439655         2.672414       35.525862
# Platinum          47.500000         2.450000       36.250000
#
#                Total_Relationship_Count  Months_Inactive_12_mon  \
# Card_Category
# Blue                           3.848665                2.345697
# Silver                         3.421622                2.273874
# Gold                           3.008621                2.310345
# Platinum                       2.300000                2.250000
#
#                Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# Card_Category
# Blue                        2.455596   7363.780002          1157.812209
# Silver                      2.450450  25277.836036          1206.129730
# ...

# %%
n=ta.pivot_table(index="Gender",columns="Card_Category",values="Credit_Limit")
n
# Out:
# Card_Category          Blue          Gold      Platinum        Silver
# Gender
# F               4308.064928  20967.000000  26280.888889  18614.752381
# M              10959.443806  32045.551282  33558.272727  29333.626087

# %%
ta["Card_Category"].value_counts().plot(kind="bar")
plt.figure(figsize=(30,25))

# %%
ta["Marital_Status"].value_counts().plot(kind="pie")
plt.figure(figsize=(45,30))

# %%
plt.scatter(ta["Credit_Limit"],ta["Total_Trans_Amt"])
plt.xlabel("Credit Limit")
plt.ylabel("Total transfer amount")
# Out:
# Text(0, 0.5, 'Total transfer amount')

# %%
sns.boxplot(x="Customer_Age",y="Gender",color="red",data=ta)
plt.xlabel("Customer Age")
plt.ylabel("Gender")
# Out:
# Text(0, 0.5, 'Gender')

# %%
count,bin_edges=np.histogram(ta["Customer_Age"])
ta["Customer_Age"].plot(kind="hist",xticks=bin_edges)
plt.xlabel("AGE")
plt.ylabel("users based on age")
plt.grid()
plt.show()

# %% [markdown]
# # **As we can see users between age 48 to 50 are maximum**

# %%
card=ta[["Card_Category","Credit_Limit"]]
g=card.groupby(["Card_Category"]).mean().sort_values(ascending=False,by="Credit_Limit")
g.plot.bar()

# %% [markdown]
# ---
#
#
# # we can see that as card tier increase with resp to credit limits

# %%
card=ta[["Card_Category","Credit_Limit"]]
g=card.groupby(["Card_Category"])#.mean().sort_values(ascending=False,by="Credit_Limit")
g.plot.bar()

# %%
from scipy import stats as st

# %%
st.f_oneway(g.get_group("Gold")["Credit_Limit"],g.get_group("Platinum")["Credit_Limit"])
# Out:
# F_onewayResult(statistic=0.8149291591487193, pvalue=0.3682868201652807)

# %% [markdown]
# There is lesser difference between top 2 tier of credit cards

# %%
p=ta.corr()

# %%
plt.subplots(figsize=(20,20))
sns.heatmap(p,annot=True)
plt.show()

# %%
sns.regplot(x="Total_Trans_Amt",y="Total_Trans_Ct",data=ta)

# %%
sns.regplot(x="Customer_Age",y="Months_on_book",data=ta,color="red")
