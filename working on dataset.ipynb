# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/MALratings.csv",converters={"Episodes":lambda x:int()})

# %%
data.head(5)
# Out:
#                                                Title                Genres  \
# 0         Kaguya-sama wa Kokurasetai: Ultra Romantic       Comedy,Suspense
# 1                         3-gatsu no Lion 2nd Season   Drama,Slice of Life
# 2  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...  Action,Comedy,Sci-Fi
# 3                                           Gintama.  Action,Comedy,Sci-Fi
# 4                                     Koe no Katachi                   NaN
#
#   Rank  Popularity  Score  Episodes   Episode length Release Date
# 0   13         404   8.99         0  23 min. per ep.  Spring 2022
# 1   14         533   8.96         0  25 min. per ep.    Fall 2017
# 2   19         939   8.93         0    1 hr. 50 min.          NaN
# 3   12         735   8.99         0  24 min. per ep.  Winter 2017
# 4   15          19   8.96         0    2 hr. 10 min.          NaN

# %%
data.tail(4)
# Out:
#                                         Title                          Genres  \
# 20339                              High Score            Comedy,Slice of Life
# 20340                                Noraneko                             NaN
# 20341  Suki de Suki de, Suki de The Animation                             NaN
# 20342                 Koihime†Musou OVA Omake  Adventure,Comedy,Fantasy,Ecchi
#
#         Rank  Popularity  Score  Episodes   Episode length Release Date
# 20339  10527        6095   5.58         0   3 min. per ep.    Fall 2011
# 20340   8706        5064   6.04         0          35 sec.          NaN
# 20341     /A        5329   6.81         0  27 min. per ep.          NaN
# 20342   8328       10052   6.12         0          12 min.          NaN

# %%
data.describe()
# Out:
#          Popularity         Score  Episodes
# count  20343.000000  14019.000000   20343.0
# mean   10174.477953      6.451633       0.0
# std     5874.844237      0.905774       0.0
# min        1.000000      1.840000       0.0
# 25%     5086.500000      5.830000       0.0
# 50%    10175.000000      6.460000       0.0
# 75%    15263.500000      7.110000       0.0
# max    20349.000000      9.140000       0.0

# %%
data.dtypes
# Out:
# Title              object
# Genres             object
# Rank               object
# Popularity          int64
# Score             float64
# Episodes            int64
# Episode length     object
# Release Date       object
# dtype: object

# %%
data.columns
# Out:
# Index(['Title', 'Genres', 'Rank', 'Popularity', 'Score', 'Episodes',
#        'Episode length', 'Release Date'],
#       dtype='object')

# %%
data.isna()
# Out:
#        Title  Genres   Rank  Popularity  Score  Episodes  Episode length  \
# 0      False   False  False       False  False     False           False
# 1      False   False  False       False  False     False           False
# 2      False   False  False       False  False     False           False
# 3      False   False  False       False  False     False           False
# 4      False    True  False       False  False     False           False
# ...      ...     ...    ...         ...    ...       ...             ...
# 20338  False   False  False       False  False     False           False
# 20339  False   False  False       False  False     False           False
# 20340  False    True  False       False  False     False           False
# 20341  False    True  False       False  False     False           False
# 20342  False   False  False       False  False     False           False
#
#        Release Date
# 0             False
# 1             False
# 2              True
# ...

# %%
data.isna().sum()
# Out:
# Title                 0
# Genres            10327
# Rank                  0
# Popularity            0
# Score                 0
# Episodes              0
# Episode length        0
# Release Date      15256
# dtype: int64

# %%
mean=data["Score"].mean()
mean
# Out:
# 6.45163278407875

# %%
data["Score"].fillna(mean,inplace=True)

# %%
data.tail(5)
# Out:
#                                         Title                          Genres  \
# 20338                             Steins;Gate           Drama,Sci-Fi,Suspense
# 20339                              High Score            Comedy,Slice of Life
# 20340                                Noraneko                             NaN
# 20341  Suki de Suki de, Suki de The Animation                             NaN
# 20342                 Koihime†Musou OVA Omake  Adventure,Comedy,Fantasy,Ecchi
#
#         Rank  Popularity  Score  Episodes   Episode length Release Date
# 20338      4          13   9.08         0  24 min. per ep.  Spring 2011
# 20339  10527        6095   5.58         0   3 min. per ep.    Fall 2011
# 20340   8706        5064   6.04         0          35 sec.          NaN
# 20341     /A        5329   6.81         0  27 min. per ep.          NaN
# 20342   8328       10052   6.12         0          12 min.          NaN

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of                                                    Title  \
# 0             Kaguya-sama wa Kokurasetai: Ultra Romantic
# 1                             3-gatsu no Lion 2nd Season
# 2      Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 3                                               Gintama.
# 4                                         Koe no Katachi
# ...                                                  ...
# 20338                                        Steins;Gate
# 20339                                         High Score
# 20340                                           Noraneko
# 20341             Suki de Suki de, Suki de The Animation
# 20342                            Koihime†Musou OVA Omake
#
#                                Genres   Rank  Popularity  Score  Episodes  \
# 0                     Comedy,Suspense     13         404   8.99         0
# 1                 Drama,Slice of Life     14         533   8.96         0
# ...

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of                                                    Title  \
# 0             Kaguya-sama wa Kokurasetai: Ultra Romantic
# 1                             3-gatsu no Lion 2nd Season
# 2      Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 3                                               Gintama.
# 4                                         Koe no Katachi
# ...                                                  ...
# 20338                                        Steins;Gate
# 20339                                         High Score
# 20340                                           Noraneko
# 20341             Suki de Suki de, Suki de The Animation
# 20342                            Koihime†Musou OVA Omake
#
#                                Genres   Rank  Popularity  Score  Episodes  \
# 0                     Comedy,Suspense     13         404   8.99         0
# 1                 Drama,Slice of Life     14         533   8.96         0
# ...

# %%
data["Genres"].unique
# Out:
# <bound method Series.unique of 0                       Comedy,Suspense
# 1                   Drama,Slice of Life
# 2                  Action,Comedy,Sci-Fi
# 3                  Action,Comedy,Sci-Fi
# 4                                   NaN
#                       ...
# 20338             Drama,Sci-Fi,Suspense
# 20339              Comedy,Slice of Life
# 20340                               NaN
# 20341                               NaN
# 20342    Adventure,Comedy,Fantasy,Ecchi
# Name: Genres, Length: 20343, dtype: object>

# %%
us[(us["age"]>40)&( us["occupation"]=="technician")]

# %%
data[(data["Score"]<9)&(data["Popularity"]>20345)]
# Out:
#                                 Title               Genres   Rank  Popularity  \
# 3105                 Zui Ke Ai De Ren                  NaN  15750       20347
# 5318                 Zuoshou Shanglan                  NaN     /A       20349
# 7701         Zui Ke Ai De Ren (Movie)                  NaN  15751       20348
# 7703  Zoku Zou no Senaka: Baton Touch  Drama,Slice of Life  15743       20346
#
#          Score  Episodes   Episode length Release Date
# 3105  6.451633         0  40 min. per ep.          NaN
# 5318  6.451633         0          Unknown          NaN
# 7701  6.451633         0    1 hr. 24 min.          NaN
# 7703  6.451633         0           6 min.          NaN

# %%
data["Popularity"].max()
# Out:
# 20349
