# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
am=pd.read_csv("/content/vehicle_data.csv")

# %%
am.head()
# Out:
#                                           Title  \
# 0                Micro Panda Auto 2019 for sale
# 1  Toyota GT86 Company Maintained 2013 for sale
# 2           Toyota IST FL , GRADE 2003 for sale
# 3               Toyota Allion 240 2002 for sale
# 4              Micro Panda LC 1.0 2015 for sale
#
#                                        Sub_title          Price   Brand  \
# 0     Posted on 02 Jul 6:27 am, Kesbewa, Colombo   Rs 2,795,000   Micro
# 1  Posted on 15 Jun 7:38 pm, Rajagiriya, Colombo  Rs 11,500,000  Toyota
# 2   Posted on 05 Jul 1:36 pm, Marawila, Puttalam   Rs 3,300,000  Toyota
# 3    Posted on 05 Jul 1:33 pm, Peradeniya, Kandy   Rs 4,450,000  Toyota
# 4   Posted on 05 Jul 1:30 pm, Veyangoda, Gampaha   Rs 2,173,000   Micro
#
#     Model             Edition    Year Condition Transmission           Body  \
# 0   Panda                Auto  2019.0      Used    Automatic      Hatchback
# 1    GT86  Company Maintained  2013.0      Used    Automatic  Coup̩/Sports
# ...

# %%
am.dtypes
# Out:
# Title              object
# Sub_title          object
# Price              object
# Brand              object
# Model              object
# Edition            object
# Year              float64
# Condition          object
# Transmission       object
# Body               object
# Fuel               object
# Capacity           object
# Mileage            object
# Location           object
# Description        object
# Post_URL           object
# Seller_name        object
# Seller_type        object
# published_date     object
# dtype: object

# %%
sns.heatmap(am.isnull())

# %%
am.isna()
# Out:
#        Title  Sub_title  Price  Brand  Model  Edition   Year  Condition  \
# 0      False      False  False  False  False    False  False      False
# 1      False      False  False  False  False    False  False      False
# 2      False      False  False  False  False    False  False      False
# 3      False      False  False  False  False    False  False      False
# 4      False      False  False  False  False    False  False      False
# ...      ...        ...    ...    ...    ...      ...    ...        ...
# 13717  False      False  False  False  False    False  False      False
# 13718  False      False  False  False  False     True  False      False
# 13719  False      False  False  False  False    False  False      False
# 13720  False      False  False  False  False    False  False      False
# 13721  False      False  False  False  False    False   True       True
#
#        Transmission   Body   Fuel  Capacity  Mileage  Location  Description  \
# ...

# %%
am.isna().sum()
# Out:
# Title                0
# Sub_title            0
# Price                0
# Brand                0
# Model                0
# Edition           3316
# Year                 1
# Condition            1
# Transmission         1
# Body              1099
# Fuel                 1
# Capacity             1
# Mileage              1
# Location             1
# Description          1
# Post_URL             1
# Seller_name          1
# Seller_type          1
# published_date       1
# dtype: int64

# %%
plt.scatter(am["Brand"].head(30),am["Price"].head(30))
plt.xlabel("Brand")
plt.ylabel("Price")
plt.figure(figsize=(60,60))
plt.show()

# %%
new=pd.read_csv("/content/MALratings.csv")

# %%
new.head(5)
# Out:
#                                                Title                Genres  \
# 0         Kaguya-sama wa Kokurasetai: Ultra Romantic       Comedy,Suspense
# 1                         3-gatsu no Lion 2nd Season   Drama,Slice of Life
# 2  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...  Action,Comedy,Sci-Fi
# 3                                           Gintama.  Action,Comedy,Sci-Fi
# 4                                     Koe no Katachi                   NaN
#
#   Rank  Popularity  Score Episodes   Episode length Release Date
# 0   13         404   8.99       12  23 min. per ep.  Spring 2022
# 1   14         533   8.96       22  25 min. per ep.    Fall 2017
# 2   19         939   8.93        1    1 hr. 50 min.          NaN
# 3   12         735   8.99       12  24 min. per ep.  Winter 2017
# 4   15          19   8.96        1    2 hr. 10 min.          NaN

# %%
new.dtypes
# Out:
# Title              object
# Genres             object
# Rank               object
# Popularity          int64
# Score             float64
# Episodes           object
# Episode length     object
# Release Date       object
# dtype: object

# %%
n=new.head(50)

# %%
sns.boxplot(x="Popularity",y="Score",data=n)

# %%
d=pd.read_csv("/content/odi-batting.csv")

# %%
d.head(20)
# Out:
#         Country            Player   Runs  ScoreRate   MatchDate  \
# 0   Afghanistan  Mohammad Shahzad  118.0      97.52   2-16-2010
# 1   Afghanistan  Mohammad Shahzad  110.0      99.09    9-1-2009
# 2   Afghanistan  Mohammad Shahzad  100.0     138.88   8-16-2010
# 3   Afghanistan  Mohammad Shahzad   82.0      75.92   7-10-2010
# 4   Afghanistan  Mohammad Shahzad   57.0     100.00    7-1-2010
# 5   Afghanistan  Mohammad Shahzad   55.0      87.30    7-7-2010
# 6   Afghanistan  Mohammad Shahzad   37.0      80.43   10-9-2010
# 7   Afghanistan  Mohammad Shahzad   34.0      77.27    7-9-2010
# 8   Afghanistan  Mohammad Shahzad   20.0      90.90    7-5-2010
# 9   Afghanistan  Mohammad Shahzad   16.0      57.14   8-30-2009
# 10  Afghanistan  Mohammad Shahzad   11.0     100.00   8-17-2010
# 11  Afghanistan  Mohammad Shahzad    8.0      80.00    8-9-2011
# 12  Afghanistan  Mohammad Shahzad    2.0      50.00    7-3-2010
# 13  Afghanistan  Mohammad Shahzad    1.0      25.00   10-7-2010
# ...

# %%
d.describe()
# Out:
#                Runs     ScoreRate
# count  55926.000000  55926.000000
# mean      22.241607     65.314105
# std       25.552423     44.203144
# min        0.000000      0.000000
# 25%        4.000000     37.500000
# 50%       13.000000     62.710000
# 75%       32.000000     87.500000
# max      200.000000    600.000000

# %%
d.isna().sum()
# Out:
# Country      0
# Player       0
# Runs         0
# ScoreRate    0
# MatchDate    0
# Ground       0
# Versus       0
# URL          0
# dtype: int64

# %%
d.dtypes
# Out:
# Country       object
# Player        object
# Runs         float64
# ScoreRate    float64
# MatchDate     object
# Ground        object
# Versus        object
# URL           object
# dtype: object

# %%
sns.boxplot(x="ScoreRate",y="Runs",color="Red",data=d)

# %%
d["ScoreRate"].mean()
# Out:
# 65.31410526463202

# %%
d["Runs"].mean()
# Out:
# 22.241607356571468

# %%
d["ScoreRate"].fillna(65.09311653116531,inplace=True)

# %%
d["Runs"].fillna(22.658962446767326,inplace=True)

# %%
sns.heatmap(d.isnull())

# %%
q=d[(d["Country"]=="India")&(d["ScoreRate"]>80.00)&(d["Runs"]>100.0)]
q
# Out:
#       Country              Player   Runs  ScoreRate   MatchDate  \
# 15150   India  Sachin R Tendulkar  200.0     136.05   2-24-2010
# 15151   India  Sachin R Tendulkar  186.0     124.00   11-8-1999
# 15152   India  Sachin R Tendulkar  175.0     124.11   11-5-2009
# 15153   India  Sachin R Tendulkar  163.0     122.55    3-8-2009
# 15154   India  Sachin R Tendulkar  152.0     100.66   2-23-2003
# ...       ...                 ...    ...        ...         ...
# 19461   India       Dinesh Mongia  159.0     108.16   3-19-2002
# 20054   India      Yusuf K Pathan  123.0     128.12   12-7-2010
# 20055   India      Yusuf K Pathan  105.0     150.00   1-23-2011
# 20129   India         Raman Lamba  102.0      85.00   10-7-1986
# 20574   India       Chetan Sharma  101.0     105.20  10-25-1989
#
#                                    Ground        Versus  \
# 15150          Captain Roop Singh Stadium  South Africa
# 15151         Lal Bahadur Shastri Stadium   New Zealand
# ...

# %%
plt.scatter(q["ScoreRate"],q["Runs"])

# %%
sns.boxplot(y="ScoreRate",x="Runs",color="pink",data=q)
plt.xlabel("Runs")
plt.ylabel("score rate")
# Out:
# Text(0, 0.5, 'score rate')
