# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
auto=pd.read_csv("/content/automobile.csv")

# %%
sales=pd.read_csv("/content/supermarket_sales - Sheet1.csv")

# %%
sales.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
auto.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
a=auto.corr()

# %%
plt.subplots(figsize=(20,20))
sns.heatmap(a,annot=True)
plt.show()

# %%
sales.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
c=sales.corr()

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(c,annot=True)
plt.show()

# %%
sns.regplot(x="Branch",y="cogs",data=sales)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-41-104d89ac4b9f> in <module>
# ----> 1 sns.regplot(x="Branch",y="cogs",data=sales)
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861     scatter_kws["marker"] = marker
#     862     line_kws = {} if line_kws is None else copy.copy(line_kws)
# ...

# %%
sns.regplot(x="length",y="price",data=auto)

# %%
anime=pd.read_csv("/MALratings.csv")

# %%
anime.head(10)
# Out:
#                                                Title  \
# 0         Kaguya-sama wa Kokurasetai: Ultra Romantic
# 1                         3-gatsu no Lion 2nd Season
# 2  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 3                                           Gintama.
# 4                                     Koe no Katachi
# 5                         Mo Dao Zu Shi: Wanjie Pian
# 6                    Code Geass: Hangyaku no Lelouch
# 7                                            Gintama
# 8                               Ginga Eiyuu Densetsu
# 9  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
#
#                       Genres Rank  Popularity  Score Episodes  \
# 0            Comedy,Suspense   13         404   8.99       12
# 1        Drama,Slice of Life   14         533   8.96       22
# 2       Action,Comedy,Sci-Fi   19         939   8.93        1
# 3       Action,Comedy,Sci-Fi   12         735   8.99       12
# 4                        NaN   15          19   8.96        1
# ...

# %%
sns.regplot(x="Popularity",y="Score",data=anime)

# %%
anime.shape
# Out:
# (20343, 8)

# %%
data1=anime[["Genres","Score"]]
data1.groupby(["Score"])
data1.plot.bar()

# %%
ano=anime[["Genres","Rank"]].groupby(["Genres"])
ano

# %%
stats.f_oneway(ano.get_group("Action,Comedy,Sci-Fi")["Rank"],ano.get_group("Comedy,Suspense")["Rank"])
# Out:
# F_onewayResult(statistic=0.23297316331499682, pvalue=0.630526529320401)
